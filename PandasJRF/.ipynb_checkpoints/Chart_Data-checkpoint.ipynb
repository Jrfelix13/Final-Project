# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import sem
import numpy as np
from scipy.stats import linregress

POSTGRES = {
    'user': 'root',
    'pw': 'FinalProject_2020',
    'db': 'final_project_db',
    'host': 'finalprojectdb.cyj4dabyex0o.us-east-2.rds.amazonaws.com',
    'port': '5432',
}
engine = create_engine('postgresql://%(user)s:\
%(pw)s@%(host)s:%(port)s/%(db)s' % POSTGRES)

# %%
Base = automap_base()
Base.prepare(engine,reflect=True)
# reflect the tables
Base.classes.keys()
# Out:
# ['aisle_tbl',
#  'product_tbl',
#  'department_tbl',
#  'orders_tbl',
#  'orders_product_prior',
#  'orders_product_train']

# %%
session = Session(engine)

# %%
Aisle = Base.classes.aisle_tbl
Product = Base.classes.product_tbl
Department = Base.classes.department_tbl
Orders = Base.classes.orders_tbl
OrdersP = Base.classes.orders_product_prior
OrdersT = Base.classes.orders_product_train

# %%
number_of_dep = session.query(Department)
number_of_dep

# %%
last_year_prcp_df = pd.DataFrame(number_of_dep)
last_year_prcp_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-f00741f6b566> in <module>
# ----> 1 last_year_prcp_df = pd.DataFrame(number_of_dep)
#       2 last_year_prcp_df
#
# ~\Anaconda3\envs\DATAJR\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     420                                          dtype=values.dtype, copy=False)
#     421             else:
# --> 422                 raise ValueError('DataFrame constructor not properly called!')
#     423
#     424         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
products_df=pd.read_csv("Data/products.csv")
Orders_df=pd.read_csv("Data/order_products__prior.csv")
departments_df=pd.read_csv("Data/departments.csv")
info_df=pd.read_csv("Data/orders.csv")

# %%
pie_df=pd.merge(products_df,Orders_df, on="product_id", how="outer")

# %%
pie_df.head(60)
# Out:
#     product_id                product_name  aisle_id  department_id  order_id  \
# 0            1  Chocolate Sandwich Cookies        61             19    1107.0
# 1            1  Chocolate Sandwich Cookies        61             19    5319.0
# 2            1  Chocolate Sandwich Cookies        61             19    7540.0
# 3            1  Chocolate Sandwich Cookies        61             19    9228.0
# 4            1  Chocolate Sandwich Cookies        61             19    9273.0
# 5            1  Chocolate Sandwich Cookies        61             19    9696.0
# 6            1  Chocolate Sandwich Cookies        61             19   11140.0
# 7            1  Chocolate Sandwich Cookies        61             19   11485.0
# 8            1  Chocolate Sandwich Cookies        61             19   12672.0
# 9            1  Chocolate Sandwich Cookies        61             19   13668.0
# 10           1  Chocolate Sandwich Cookies        61             19   14668.0
# 11           1  Chocolate Sandwich Cookies        61             19   16132.0
# 12           1  Chocolate Sandwich Cookies        61             19   18303.0
# 13           1  Chocolate Sandwich Cookies        61             19   19479.0
# 14           1  Chocolate Sandwich Cookies        61             19   19569.0
# 15           1  Chocolate Sandwich Cookies        61             19   19879.0
# 16           1  Chocolate Sandwich Cookies        61             19   19939.0
# 17           1  Chocolate Sandwich Cookies        61             19   19989.0
# 18           1  Chocolate Sandwich Cookies        61             19   23202.0
# 19           1  Chocolate Sandwich Cookies        61             19   24367.0
# 20           1  Chocolate Sandwich Cookies        61             19   24760.0
# 21           1  Chocolate Sandwich Cookies        61             19   25365.0
# 22           1  Chocolate Sandwich Cookies        61             19   26490.0
# 23           1  Chocolate Sandwich Cookies        61             19   29334.0
# 24           1  Chocolate Sandwich Cookies        61             19   33675.0
# 45           1  Chocolate Sandwich Cookies        61             19   77436.0
# 46           1  Chocolate Sandwich Cookies        61             19   79107.0
# 47           1  Chocolate Sandwich Cookies        61             19   82631.0
# 48           1  Chocolate Sandwich Cookies        61             19   82660.0
# 49           1  Chocolate Sandwich Cookies        61             19   85158.0
# 50           1  Chocolate Sandwich Cookies        61             19   85932.0
# 51           1  Chocolate Sandwich Cookies        61             19   87625.0
# 52           1  Chocolate Sandwich Cookies        61             19   87946.0
# 53           1  Chocolate Sandwich Cookies        61             19   93380.0
# 54           1  Chocolate Sandwich Cookies        61             19   95868.0
# 55           1  Chocolate Sandwich Cookies        61             19   97398.0
# 56           1  Chocolate Sandwich Cookies        61             19  101004.0
# 57           1  Chocolate Sandwich Cookies        61             19  104144.0
# 58           1  Chocolate Sandwich Cookies        61             19  105333.0
# 59           1  Chocolate Sandwich Cookies        61             19  107716.0
#
#     add_to_cart_order  reordered department
# 0                 7.0        0.0     snacks
# 1                 3.0        1.0     snacks
# 2                 4.0        1.0     snacks
# 3                 2.0        0.0     snacks
# 4                30.0        0.0     snacks
# 5                 5.0        1.0     snacks
# 6                 1.0        1.0     snacks
# 7                 4.0        0.0     snacks
# 8                 3.0        1.0     snacks
# 9                 4.0        1.0     snacks
# 10               13.0        1.0     snacks
# 11                1.0        1.0     snacks
# 12                1.0        1.0     snacks
# 13                5.0        0.0     snacks
# 14                9.0        1.0     snacks
# 15               12.0        0.0     snacks
# 16                2.0        0.0     snacks
# 17                1.0        0.0     snacks
# 18                3.0        0.0     snacks
# 19                2.0        1.0     snacks
# 20                5.0        1.0     snacks
# 21                9.0        1.0     snacks
# 22               14.0        1.0     snacks
# 23                5.0        1.0     snacks
# 24               10.0        1.0     snacks
# 25               14.0        0.0     snacks
# 26                6.0        1.0     snacks
# 27                6.0        0.0     snacks
# 28                5.0        1.0     snacks
# 29                2.0        1.0     snacks
# 30                4.0        1.0     snacks
# 31                6.0        1.0     snacks
# 32                4.0        1.0     snacks
# 33                3.0        1.0     snacks
# 34                1.0        0.0     snacks
# 35                4.0        1.0     snacks
# 36                1.0        1.0     snacks
# 37                5.0        1.0     snacks
# 38                6.0        0.0     snacks
# 39                1.0        1.0     snacks
# 40                3.0        1.0     snacks
# 41               14.0        1.0     snacks
# 42                3.0        1.0     snacks
# 43                7.0        1.0     snacks
# 44                4.0        0.0     snacks
# 45                1.0        0.0     snacks
# 46               10.0        0.0     snacks
# 47                2.0        1.0     snacks
# 48               11.0        1.0     snacks
# 49                1.0        1.0     snacks
# 50                4.0        0.0     snacks
# 51               14.0        0.0     snacks
# 52                5.0        1.0     snacks
# 53                8.0        1.0     snacks
# 54                3.0        1.0     snacks
# 55                1.0        1.0     snacks
# 56                1.0        1.0     snacks
# 57                5.0        1.0     snacks
# 58                2.0        1.0     snacks
# 59               11.0        0.0     snacks

# %%
ps=pie_df.groupby(["product_name"])
o_ps= ps["order_id"].nunique()
order_product=pd.DataFrame(o_ps)
order_product.columns=["Total_product"]
order_product.sort_values(by=['Total_product'], inplace=True, ascending=False)
order_product=order_product.reset_index()
product_name=order_product["product_name"]
order_product
# Out:
#                                             product_name  Total_product
# 0                                                 Banana         472565
# 1                                 Bag of Organic Bananas         379450
# 2                                   Organic Strawberries         264683
# 3                                   Organic Baby Spinach         241921
# 4                                   Organic Hass Avocado         213584
# 5                                        Organic Avocado         176815
# 6                                            Large Lemon         152657
# 7                                           Strawberries         142951
# 8                                                  Limes         140627
# 9                                     Organic Whole Milk         137905
# 10                                   Organic Raspberries         137057
# 11                                  Organic Yellow Onion         113426
# 12                                        Organic Garlic         109778
# 13                                      Organic Zucchini         104823
# 14                                   Organic Blueberries         100060
# 15                                        Cucumber Kirby          97315
# 16                                    Organic Fuji Apple          89632
# 17                                         Organic Lemon          87746
# 18                              Apple Honeycrisp Organic          85020
# 19                                Organic Grape Tomatoes          84255
# 20                                   Seedless Red Grapes          82689
# 21                                      Organic Cucumber          80392
# 22                                      Honeycrisp Apple          79769
# 23                                  Organic Baby Carrots          76896
# 24                                   Organic Half & Half          76360
# 25                            Sparkling Water Grapefruit          75886
# 26                  Organic Large Extra Fancy Fuji Apple          75165
# 27                                         Yellow Onions          73167
# 28                                   Organic Gala Apples          72846
# 29                                  Organic Baby Arugula          72829
# ...                                                  ...            ...
# 49658          Vegan Coconut Milk Caramels With Sea Salt              1
# 49659                         The Ultimate Caramel Suace              1
# 49660         Original Salted Caramel Protein Energy Bar              1
# 49661                               Ginseng Vitality Tea              1
# 49662                               Chewy Chocolate Chip              1
# 49663                           Pumpkin Spice Almond Nog              1
# 49664                                  Jamaican Allspice              1
# 49665                                  Cld/Flu Van Chrry              1
# 49666                                      Easter Basket              1
# 49667                   Skin Firming Cellulite Gel Cream              1
# 49668                                     Original Lager              1
# 49669       Organic Finely Shredded Sharp Cheddar Cheese              1
# 49670            Spinach Cheese Rice Palak Paneer Dinner              1
# 49671            Blueberry Blast Fruit and Chia Seed Bar              1
# 49672                    Gluten Free Almond Snap Cookies              1
# 49673                                     Original Jerky              1
# 49674                          Kb Clb Stick Organic Fmly              1
# 49675                                    Kefir Raspberry              1
# 49676                                    Orange Recharge              1
# 49677    Single Barrel Kentucky Straight Bourbon Whiskey              0
# 49678             Unpeeled Apricot Halves in Heavy Syrup              0
# 49679                         12 Inch Taper Candle White              0
# 49680                                 Chocolate Go Bites              0
# 49681                            Pure Squeezed  Lemonade              0
# 49682                  Non-Dairy Coconut Seven Layer Bar              0
# 49683                        Protein Granola Apple Crisp              0
# 49684                            Water With Electrolytes              0
# 49685                   Wasabi Cheddar Spreadable Cheese              0
# 49686  Ultra Sun Blossom Liquid 90 loads Fabric Enhan...              0
# 49687                               Sweetart Jelly Beans              0
#
# [49688 rows x 2 columns]

# %%
Top_order_product=pd.DataFrame(order_product.head(10))
Top_order_product
# Out:
#              product_name  Total_product
# 0                  Banana         472565
# 1  Bag of Organic Bananas         379450
# 2    Organic Strawberries         264683
# 3    Organic Baby Spinach         241921
# 4    Organic Hass Avocado         213584
# 5         Organic Avocado         176815
# 6             Large Lemon         152657
# 7            Strawberries         142951
# 8                   Limes         140627
# 9      Organic Whole Milk         137905

# %%
plt.title("#of orders by product")
plt.pie(Top_order_product["Total_product"],
        autopct="%1.1f%%", shadow=True, startangle=90)
plt.axis("equal")
plt.show()

# %%
ds=pie_df_2.groupby(["department"])
o_ds= ds["order_id"].nunique()
order_departments=pd.DataFrame(o_ds)
order_departments.columns=["Total_departments"]
order_departments.sort_values(by=['Total_departments'], inplace=True, ascending=False)
order_departments=order_departments.reset_index()
department=order_departments["department"]
Total_Count_by_departments=order_departments["Total_departments"]
order_departments
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-3d40a8d92cc1> in <module>
# ----> 1 ds=pie_df_2.groupby(["department"])
#       2 o_ds= ds["order_id"].nunique()
#       3 order_departments=pd.DataFrame(o_ds)
#       4 order_departments.columns=["Total_departments"]
#       5 order_departments.sort_values(by=['Total_departments'], inplace=True, ascending=False)
#
# ~\Anaconda3\envs\DATAJR\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda3\envs\DATAJR\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# ~\Anaconda3\envs\DATAJR\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# ~\Anaconda3\envs\DATAJR\lib\site-packages\pandas\core\groupby\groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3289                 in_axis, name, level, gpr = False, None, gpr, None
#    3290             else:
# -> 3291                 raise KeyError(gpr)
#    3292         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    3293             # Add key to exclusions
#
# KeyError: 'department'

# %%
order_departments2=pd.DataFrame(order_departments.head(10))
order_departments.Total_departments.iloc[10:].sum
# Out:
#         department  Total_departments
# 0          produce            2409320
# 1       dairy eggs            2177338
# 2        beverages            1457351
# 3           snacks            1391447
# 4           frozen            1181018
# 5           pantry            1117892
# 6           bakery             881556
# 7             deli             770300
# 8     canned goods             681305
# 9  dry goods pasta             597862

# %%
plt.title("#of orders by deparment")
plt.pie(order_departments["Total_departments"],
        autopct="%1.1f%%", shadow=True, startangle=90)
plt.axis("equal")
plt.show()

# %%
order_departments.to_json(r'Data\department.json', orient='records')

# %%
Top_order_product.to_json(r'Data\products.json', orient='records')

# %%
tab_df=pd.merge(Orders_df,info_df, on="order_id", how="outer")

# %%
tab_df
# Out:
#           order_id  product_id  add_to_cart_order  reordered  user_id  \
# 0                2     33120.0                1.0        1.0   202279
# 1                2     28985.0                2.0        1.0   202279
# 2                2      9327.0                3.0        0.0   202279
# 3                2     45918.0                4.0        1.0   202279
# 4                2     30035.0                5.0        0.0   202279
# 5                2     17794.0                6.0        1.0   202279
# 6                2     40141.0                7.0        1.0   202279
# 7                2      1819.0                8.0        1.0   202279
# 8                2     43668.0                9.0        0.0   202279
# 9                3     33754.0                1.0        1.0   205970
# 10               3     24838.0                2.0        1.0   205970
# 11               3     17704.0                3.0        1.0   205970
# 12               3     21903.0                4.0        1.0   205970
# 13               3     17668.0                5.0        1.0   205970
# 14               3     46667.0                6.0        1.0   205970
# 15               3     17461.0                7.0        1.0   205970
# 16               3     32665.0                8.0        1.0   205970
# 17               4     46842.0                1.0        0.0   178520
# 18               4     26434.0                2.0        1.0   178520
# 19               4     39758.0                3.0        1.0   178520
# 20               4     27761.0                4.0        1.0   178520
# 21               4     10054.0                5.0        1.0   178520
# 22               4     21351.0                6.0        1.0   178520
# 23               4     22598.0                7.0        1.0   178520
# 24               4     34862.0                8.0        1.0   178520
# 25               4     40285.0                9.0        1.0   178520
# 26               4     17616.0               10.0        1.0   178520
# 27               4     25146.0               11.0        1.0   178520
# 28               4     32645.0               12.0        1.0   178520
# 29               4     41276.0               13.0        1.0   178520
# ...            ...         ...                ...        ...      ...
# 32640668   2633505         NaN                NaN        NaN   206180
# 32640669    681092         NaN                NaN        NaN   206181
# 32640670   1836967         NaN                NaN        NaN   206182
# 32640671   2799087         NaN                NaN        NaN   206183
# 32640672     67174         NaN                NaN        NaN   206184
# 32640673   2048154         NaN                NaN        NaN   206185
# 32640674    160694         NaN                NaN        NaN   206186
# 32640675   2762353         NaN                NaN        NaN   206187
# 32640676   3367945         NaN                NaN        NaN   206188
# 32640677    959487         NaN                NaN        NaN   206189
# 32640678   2108733         NaN                NaN        NaN   206190
# 32640679   2530125         NaN                NaN        NaN   206191
# 32640680    701105         NaN                NaN        NaN   206192
# 32640681   2518868         NaN                NaN        NaN   206193
# 32640682     64567         NaN                NaN        NaN   206194
# 32640683   2986595         NaN                NaN        NaN   206195
# 32640684   3383615         NaN                NaN        NaN   206196
# 32640685   1564541         NaN                NaN        NaN   206197
# 32640686   2951304         NaN                NaN        NaN   206198
# 32640687   2585586         NaN                NaN        NaN   206199
# 32640688    943915         NaN                NaN        NaN   206200
# 32640689    309211         NaN                NaN        NaN   206201
# 32640690   2728930         NaN                NaN        NaN   206202
# 32640691   2371631         NaN                NaN        NaN   206203
# 32640692    350108         NaN                NaN        NaN   206204
# 32640693   1716008         NaN                NaN        NaN   206205
# 32640694   1043943         NaN                NaN        NaN   206206
# 32640695   2821651         NaN                NaN        NaN   206207
# 32640696    803273         NaN                NaN        NaN   206208
# 32640697    272231         NaN                NaN        NaN   206209
#
#          eval_set  order_number  order_dow  order_hour_of_day  \
# 0           prior             3          5                  9
# 1           prior             3          5                  9
# 2           prior             3          5                  9
# 3           prior             3          5                  9
# 4           prior             3          5                  9
# 5           prior             3          5                  9
# 6           prior             3          5                  9
# 7           prior             3          5                  9
# 8           prior             3          5                  9
# 9           prior            16          5                 17
# 10          prior            16          5                 17
# 11          prior            16          5                 17
# 12          prior            16          5                 17
# 13          prior            16          5                 17
# 14          prior            16          5                 17
# 15          prior            16          5                 17
# 16          prior            16          5                 17
# 17          prior            36          1                  9
# 18          prior            36          1                  9
# 19          prior            36          1                  9
# 20          prior            36          1                  9
# 21          prior            36          1                  9
# 22          prior            36          1                  9
# 23          prior            36          1                  9
# 24          prior            36          1                  9
# 25          prior            36          1                  9
# 26          prior            36          1                  9
# 27          prior            36          1                  9
# 28          prior            36          1                  9
# 29          prior            36          1                  9
# ...           ...           ...        ...                ...
# 32640668     test            19          0                 13
# 32640669    train            15          1                 13
# 32640670     test            11          0                 10
# 32640671     test            15          0                 13
# 32640672    train             5          1                 15
# 32640673    train            11          4                 13
# 32640674    train             4          5                 15
# 32640675     test            35          0                  0
# 32640676    train             8          1                 21
# 32640677     test             7          2                 20
# 32640678    train             9          5                 14
# 32640679    train             6          0                  9
# 32640680     test            15          6                 19
# 32640681    train            42          5                 12
# 32640682     test            12          4                  0
# 32640683    train            20          0                 14
# 32640684    train             5          0                 15
# 32640685     test            24          0                 14
# 32640686    train             8          6                 12
# 32640687    train            20          2                 16
# 32640688    train            24          6                 19
# 32640689     test            33          0                 12
# 32640690     test            23          2                 17
# 32640691    train             6          4                 19
# 32640692     test             5          4                 14
# 32640693    train             4          1                 16
# 32640694     test            68          0                 20
# 32640695     test            17          2                 13
# 32640696     test            50          5                 11
# 32640697    train            14          6                 14
#
#           days_since_prior_order
# 0                            8.0
# 1                            8.0
# 2                            8.0
# 3                            8.0
# 4                            8.0
# 5                            8.0
# 6                            8.0
# 7                            8.0
# 8                            8.0
# 9                           12.0
# 10                          12.0
# 11                          12.0
# 12                          12.0
# 13                          12.0
# 14                          12.0
# 15                          12.0
# 16                          12.0
# 17                           7.0
# 18                           7.0
# 19                           7.0
# 20                           7.0
# 21                           7.0
# 22                           7.0
# 23                           7.0
# 24                           7.0
# 25                           7.0
# 26                           7.0
# 27                           7.0
# 28                           7.0
# 29                           7.0
# ...                          ...
# 32640668                     7.0
# 32640669                    30.0
# 32640670                    20.0
# 32640671                    29.0
# 32640672                    30.0
# 32640673                    20.0
# 32640674                     7.0
# 32640675                    20.0
# 32640676                    30.0
# 32640677                     9.0
# 32640678                    30.0
# 32640679                    30.0
# 32640680                     4.0
# 32640681                     5.0
# 32640682                     6.0
# 32640683                    30.0
# 32640684                    30.0
# 32640685                    30.0
# 32640686                    30.0
# 32640687                    30.0
# 32640688                     6.0
# 32640689                    11.0
# 32640690                     6.0
# 32640691                    30.0
# 32640692                    14.0
# 32640693                    10.0
# 32640694                     0.0
# 32640695                    14.0
# 32640696                     4.0
# 32640697                    30.0
#
# [32640698 rows x 10 columns]

# %%
uo=tab_df.groupby(["user_id"])
o_u= uo["order_id"].nunique()
order_user=pd.DataFrame(o_u)
order_user.columns=["Total_user"]
order_user.sort_values(by=['Total_user'], inplace=True, ascending=False)
order_user=order_user.reset_index()
user=order_user["user_id"]
Total_Count_by_user=order_user["Total_user"]
order_user
# Out:
#         user_id  Total_user
# 0        152340         100
# 1        185641         100
# 2        185524         100
# 3         81678         100
# 4         70922         100
# 5        136870         100
# 6         81704         100
# 7        119932         100
# 8        119835         100
# 9         91035         100
# 10        24531         100
# 11       166136         100
# 12        76594         100
# 13        24562         100
# 14        12641         100
# 15       166083         100
# 16       101797         100
# 17        52868         100
# 18        63793         100
# 19       166725         100
# 20        76678         100
# 21       185406         100
# 22        70860         100
# 23       166786         100
# 24       166785         100
# 25        81625         100
# 26       185457         100
# 27       101779         100
# 28       136724         100
# 29       136737         100
# ...         ...         ...
# 206179   111377           4
# 206180    13091           4
# 206181    58062           4
# 206182    13058           4
# 206183   111427           4
# 206184   111428           4
# 206185    92107           4
# 206186   154161           4
# 206187   111460           4
# 206188    70219           4
# 206189    92110           4
# 206190   154171           4
# 206191    58035           4
# 206192   111457           4
# 206193    13040           4
# 206194   111455           4
# 206195    31778           4
# 206196    58044           4
# 206197   185058           4
# 206198   154185           4
# 206199    70209           4
# 206200   185055           4
# 206201   111446           4
# 206202    31774           4
# 206203   111443           4
# 206204    13046           4
# 206205    70208           4
# 206206   111440           4
# 206207    31762           4
# 206208    47980           4
#
# [206209 rows x 2 columns]
